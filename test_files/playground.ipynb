-- %%
select * from finguard.silver.customers
-- Out:
-- StructType([StructField('customer_id', StringType(), True), StructField('first_name', StringType(), True), StructField('last_name', StringType(), True), StructField('gender', StringType(), True), StructField('age', IntegerType(), True), StructField('city', StringType(), True), StructField('state', StringType(), True), StructField('country', StringType(), True), StructField('annual_income', DecimalType(18,2), True), StructField('customer_segment', StringType(), True), StructField('account_open_date', DateType(), True), StructField('risk_score', IntegerType(), True), StructField('preferred_spending_min', DecimalType(18,2), True), StructField('preferred_spending_max', DecimalType(18,2), True), StructField('preferred_city', StringType(), True), StructField('preferred_country', StringType(), True), StructField('trusted_device_id', StringType(), True), StructField('card_number', StringType(), True), StructField('card_type', StringType(), True), StructField('email', StringType(), True), St
-- ...

-- %%
select * from finguard.gold.transaction
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select * from finguard.gold.transaction_count_per_minute
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select * from finguard.gold.transaction_count_per_minute_sliding
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
